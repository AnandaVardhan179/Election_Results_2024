# %%
import matplotlib.pyplot as plt
import numpy as np


parties_2019 = ['BJD', 'BJP', 'INC', 'Others']
seats_2019 = [112, 23, 9, 3]

parties_2024 = ['BJD', 'BJP', 'INC', 'Others']
seats_2024 = [51, 78, 14, 4]
x = np.arange(len(parties_2019))
width = 0.35
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, seats_2019, width, label='2019')
rects2 = ax.bar(x + width/2, seats_2024, width, label='2024')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Parties')
ax.set_ylabel('Seats')
ax.set_title('Seats by party in Odisha Legislative Assembly (2019 vs 2024)')
ax.set_xticks(x)
ax.set_xticklabels(parties_2019)
ax.legend()


def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()
